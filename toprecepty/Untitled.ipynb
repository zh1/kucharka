# %%
import pandas

df = pandas.read_csv(r'C:\zhasek\repo\kucharka\toprecepty\data\recipe1.csv')

df
# Out:
#     recipe_source_id                                        recipe_name
# 0              74097   Palačinky ze zakysané smetany a  dětské krupičky  \
# 1              74095                    Rizoto z pánve s vepřovým masem
# 2              74094                                      Khoya paratha
# 3              74093                           Zeleninové kari s lilkem
# 4              74092  Camembert s klobásou, bramborem a cibulí z mik...
# 5              74091                                     Domácí koláčky
# 6              74090                Králičí stehna s rajčaty a fazolemi
# 7              74089                           Housková králičí polévka
# 8              74085                                 Kobližkové kytičky
# 9              74084     Vepřová panenka s višňovou omáčkou a fazolkami
# 10             74083                         Pečené proteinové koblížky
# 11             74082                     Pikantní krkovička po maďarsku
# ...
