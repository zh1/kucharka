# %%
import pandas

df = pandas.read_csv(r'C:\zhasek\repo\kucharka\toprecepty\recipe.csv')

df
# Out:
#        recipe_source_id                                        recipe_name
# 0                 74128                         Rýžové mléko a mléčná rýže  \
# 1                 74127  Kuřecí roláda s nádivkou, zabalená do listovéh...
# 2                 74126              Máslová polévka s houbami a bramborem
# 3                 74125                 Králík na smetaně z pomalého hrnce
# 4                 74124                                      Červený talíř
# ...                 ...                                                ...
# 12120             58106                                  Marocké palačinky
# 12121             58105                        Thajská polévka s krevetami
# 12122             58104                       Palačinky grófa Eszterházyho
# 12123             58103            Kachní prsa plněná mrkví na černém pivu
# 12124              4504               Drožďová polévka s medvědím česnekem
#
#                                              recipe_link
# ...
